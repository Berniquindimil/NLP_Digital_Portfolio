# %% [markdown]
# In this notebook, let us see how we can represent text using pre-trained word embedding models.
#
# # 1. Using a pre-trained word2vec model
#
# Let us take an example of a pre-trained word2vec model, and how we can use it to look for most similar words. We will use the Google News vectors embeddings.
# https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM
#
# A few other pre-trained word embedding models, and details on the means to access them through gensim can be found in:
# https://github.com/RaRe-Technologies/gensim-data

# %%
# To install only the requirements of this notebook, uncomment the lines below and run this cell

# ===========================

'''!pip install scikit-learn==0.21.3
# !pip install wget==3.2
# !pip install gensim==3.6.0
# !pip install psutil==5.4.8
# !pip install spacy==2.2.4'''

# ===========================
# Out:
# Collecting scikit-learn==0.21.3
#   Using cached scikit-learn-0.21.3.tar.gz (12.2 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.0 in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from scikit-learn==0.21.3) (1.26.4)
# Requirement already satisfied: scipy>=0.17.0 in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from scikit-learn==0.21.3) (1.13.1)
# Requirement already satisfied: joblib>=0.11 in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from scikit-learn==0.21.3) (1.4.2)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [49 lines of output]
#       /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-vedqhba3/scikit-learn_fe53ee0db93d43cd8caab0a57ef94643/setup.py:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         from pkg_resources import parse_version
#       Partial import of sklearn during the build process.
#       /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-vedqhba3/scikit-learn_fe53ee0db93d43cd8caab0a57ef94643/setup.py:122: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.command.build_ext import build_ext  # noqa
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-vedqhba3/scikit-learn_fe53ee0db93d43cd8caab0a57ef94643/setup.py", line 290, in <module>
#           setup_package()
#         File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-vedqhba3/scikit-learn_fe53ee0db93d43cd8caab0a57ef94643/setup.py", line 286, in setup_package
#           setup(**metadata)
#         File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/numpy/distutils/core.py", line 136, in setup
#           config = configuration()
#                    ^^^^^^^^^^^^^^^
#         File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-vedqhba3/scikit-learn_fe53ee0db93d43cd8caab0a57ef94643/setup.py", line 174, in configuration
#           config.add_subpackage('sklearn')
#         File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/numpy/distutils/misc_util.py", line 1050, in add_subpackage
#           config_list = self.get_subpackage(subpackage_name, subpackage_path,
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/numpy/distutils/misc_util.py", line 1016, in get_subpackage
#           config = self._get_configuration_from_setup_py(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/numpy/distutils/misc_util.py", line 958, in _get_configuration_from_setup_py
#           config = setup_module.configuration(*args)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-vedqhba3/scikit-learn_fe53ee0db93d43cd8caab0a57ef94643/sklearn/setup.py", line 62, in configuration
#           config.add_subpackage('utils')
#         File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/numpy/distutils/misc_util.py", line 1050, in add_subpackage
#           config_list = self.get_subpackage(subpackage_name, subpackage_path,
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/numpy/distutils/misc_util.py", line 1016, in get_subpackage
#           config = self._get_configuration_from_setup_py(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/numpy/distutils/misc_util.py", line 958, in _get_configuration_from_setup_py
#           config = setup_module.configuration(*args)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-vedqhba3/scikit-learn_fe53ee0db93d43cd8caab0a57ef94643/sklearn/utils/setup.py", line 8, in configuration
#           from Cython import Tempita
#       ModuleNotFoundError: No module named 'Cython'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-learn
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (scikit-learn)
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=4134d5fd50bf9bd18a7315321a5dbea7c658cf78df7c1535ac109c7a5d7a9e4e
#   Stored in directory: /Users/bernardoquindimil/Library/Caches/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Collecting gensim==3.6.0
#   Downloading gensim-3.6.0.tar.gz (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 580.5 kB/s eta 0:00:0000:0100:02
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.3 in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from gensim==3.6.0) (1.26.4)
# Requirement already satisfied: scipy>=0.18.1 in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from gensim==3.6.0) (1.13.1)
# Requirement already satisfied: six>=1.5.0 in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from gensim==3.6.0) (1.16.0)
# Requirement already satisfied: smart_open>=1.2.1 in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from gensim==3.6.0) (7.1.0)
# Requirement already satisfied: wrapt in /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages (from smart_open>=1.2.1->gensim==3.6.0) (1.17.0)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.6.0-cp311-cp311-macosx_11_0_arm64.whl size=23218278 sha256=c96553da2e63d82292fc5f50dd1c7c9377bf04ab8dd7b2533859b870bf00f48f
#   Stored in directory: /Users/bernardoquindimil/Library/Caches/pip/wheels/6b/84/4d/ea7977f42f89ebaa24f5702cc2d5013300934c7641d48c1521
# Successfully built gensim
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.3
#     Uninstalling gensim-4.3.3:
#       Successfully uninstalled gensim-4.3.3
# Successfully installed gensim-3.6.0
# Collecting psutil==5.4.8
#   Downloading psutil-5.4.8.tar.gz (422 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: psutil
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.4.8-cp311-cp311-macosx_11_0_arm64.whl size=219563 sha256=c12903f8727212d5e31200a8f444ec2378c479bb5e2dfb179cf004d5f17b622a
#   Stored in directory: /Users/bernardoquindimil/Library/Caches/pip/wheels/7c/85/90/9ef40af774d2808bd7e3839fdb6886179b7e8cce6a336fed05
# Successfully built psutil
# Installing collected packages: psutil
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.8
#     Uninstalling psutil-5.9.8:
#       Successfully uninstalled psutil-5.9.8
# Successfully installed psutil-5.4.8
# Collecting spacy==2.2.4
#   Downloading spacy-2.2.4.tar.gz (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 559.0 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [450 lines of output]
#       Collecting setuptools
#         Downloading setuptools-75.8.2-py3-none-any.whl.metadata (6.7 kB)
#       Collecting wheel
#         Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
#       Collecting cython>=0.25
#         Downloading Cython-3.0.12-py2.py3-none-any.whl.metadata (3.3 kB)
#       Collecting cymem<2.1.0,>=2.0.2
#         Using cached cymem-2.0.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.5 kB)
#       Collecting preshed<3.1.0,>=3.0.2
#         Using cached preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
#       Collecting murmurhash<1.1.0,>=0.28.0
#         Using cached murmurhash-1.0.12-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
#       Collecting thinc==7.4.0
#         Downloading thinc-7.4.0.tar.gz (1.3 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.3 MB ? eta -:--:--
#            ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.3 MB ? eta -:--:--
#            ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.3 MB ? eta -:--:--
#            ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.3 MB ? eta -:--:--
#            ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.3 MB ? eta -:--:--
#            ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.3 MB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 0.8/1.3 MB 454.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 0.8/1.3 MB 454.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 0.8/1.3 MB 454.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 0.8/1.3 MB 454.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 0.8/1.3 MB 454.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 1.0/1.3 MB 388.6 kB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 471.5 kB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting blis<0.5.0,>=0.4.0 (from thinc==7.4.0)
#         Downloading blis-0.4.1.tar.gz (1.8 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 MB ? eta -:--:--
#            ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.8 MB ? eta -:--:--
#            ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.8 MB ? eta -:--:--
#            ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.8 MB ? eta -:--:--
#            ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.8 MB 420.3 kB/s eta 0:00:04
#            ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.8 MB 420.3 kB/s eta 0:00:04
#            ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.8 MB 420.3 kB/s eta 0:00:04
#            ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.8 MB 420.3 kB/s eta 0:00:04
#            ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 1.0/1.8 MB 507.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 1.0/1.8 MB 507.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 1.0/1.8 MB 507.2 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 1.3/1.8 MB 482.6 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 1.3/1.8 MB 482.6 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 1.6/1.8 MB 538.5 kB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 1.6/1.8 MB 538.5 kB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 543.4 kB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting wasabi<1.1.0,>=0.0.9 (from thinc==7.4.0)
#         Downloading wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
#       Collecting srsly<1.1.0,>=0.0.6 (from thinc==7.4.0)
#         Downloading srsly-1.0.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
#       Collecting catalogue<1.1.0,>=0.0.7 (from thinc==7.4.0)
#         Downloading catalogue-1.0.2-py2.py3-none-any.whl.metadata (13 kB)
#       Collecting numpy>=1.7.0 (from thinc==7.4.0)
#         Using cached numpy-2.2.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
#       Collecting plac<1.2.0,>=0.9.6 (from thinc==7.4.0)
#         Downloading plac-1.1.3-py2.py3-none-any.whl.metadata (2.3 kB)
#       Collecting tqdm<5.0.0,>=4.10.0 (from thinc==7.4.0)
#         Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#       Downloading setuptools-75.8.2-py3-none-any.whl (1.2 MB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.2 MB ? eta -:--:--
#          ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.2 MB ? eta -:--:--
#          ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.2 MB ? eta -:--:--
#          ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.2 MB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.2 MB 463.4 kB/s eta 0:00:02
#          ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 0.8/1.2 MB 585.6 kB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 0.8/1.2 MB 585.6 kB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 1.0/1.2 MB 596.7 kB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 1.0/1.2 MB 596.7 kB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 594.8 kB/s eta 0:00:00
#       Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#       Downloading Cython-3.0.12-py2.py3-none-any.whl (1.2 MB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.2 MB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.2 MB ? eta -:--:--
#          ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.2 MB ? eta -:--:--
#          ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.2 MB ? eta -:--:--
#          ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/1.2 MB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.2 MB 525.0 kB/s eta 0:00:02
#          ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.2 MB 525.0 kB/s eta 0:00:02
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 0.8/1.2 MB 578.9 kB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 0.8/1.2 MB 578.9 kB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 1.0/1.2 MB 602.4 kB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 594.9 kB/s eta 0:00:00
#       Using cached cymem-2.0.11-cp311-cp311-macosx_11_0_arm64.whl (41 kB)
#       Using cached preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl (128 kB)
#       Using cached murmurhash-1.0.12-cp311-cp311-macosx_11_0_arm64.whl (26 kB)
#       Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
#       Downloading numpy-2.2.3-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.4 MB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.4 MB ? eta -:--:--
#          ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/5.4 MB ? eta -:--:--
#          ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/5.4 MB ? eta -:--:--
#          ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/5.4 MB 596.0 kB/s eta 0:00:09
#          ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5
py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             creating build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/load_nlp.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/hpbff.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/datasets.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/__init__.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/wrappers.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/visualizer.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             creating build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/attention.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/convolution.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/layernorm.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/maxout.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/embed.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/batchnorm.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/difference.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/encoder_decoder.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/multiheaded_attention.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/feed_forward.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/mish.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/affine.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/__init__.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/feature_extracter.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/model.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/function_layer.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/resnet.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/relu.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/static_vectors.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/hash_embed.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/elu.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/rnn.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/softmax.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             copying thinc/neural/_classes/selu.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural/_classes
#             creating build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_datasets.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_generic_utils.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_data_utils.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/__init__.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/_vendorized
#             creating build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/wrapt
#             copying thinc/extra/wrapt/importer.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/wrapt
#             copying thinc/extra/wrapt/__init__.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/wrapt
#             copying thinc/extra/wrapt/wrappers.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/wrapt
#             copying thinc/extra/wrapt/decorators.py -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra/wrapt
#             copying thinc/structs.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/typedefs.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/linalg.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/linalg.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/typedefs.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/__init__.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/structs.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/cpu.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/compile_time_constants.pxi -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/typedefs.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/linalg.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/structs.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc
#             copying thinc/linear/sparse.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/features.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/avgtron.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/serialize.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/linear.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/serialize.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/__init__.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/avgtron.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/features.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/sparse.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/serialize.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/linear.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/avgtron.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/features.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/linear/sparse.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/linear
#             copying thinc/neural/_aligned_alloc.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/optimizers.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/ops.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/ops.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/__init__.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/cpu.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/optimizers.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/ops.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/_aligned_alloc.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/_custom_kernels.cu -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/neural/_murmur3.cu -> build/lib.macosx-11.0-arm64-cpython-311/thinc/neural
#             copying thinc/extra/mb.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/search.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/cache.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/eg.pyx -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/__init__.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/eg.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/cache.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/search.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/mb.pxd -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/eg.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/cache.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/search.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             copying thinc/extra/mb.cpp -> build/lib.macosx-11.0-arm64-cpython-311/thinc/extra
#             running build_ext
#             building 'thinc.linalg' extension
#             creating build/temp.macosx-11.0-arm64-cpython-311
#             creating build/temp.macosx-11.0-arm64-cpython-311/thinc
#             clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/bernardoquindimil/miniconda3/include -arch arm64 -fPIC -O2 -isystem /Users/bernardoquindimil/miniconda3/include -arch arm64 -I/Users/bernardoquindimil/miniconda3/include/python3.11 -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/thinc_a726558500d94d088334d182b62628aa/include -I/Users/bernardoquindimil/miniconda3/include/python3.11 -c thinc/linalg.cpp -o build/temp.macosx-11.0-arm64-cpython-311/thinc/linalg.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             thinc/linalg.cpp:196:12: fatal error: 'longintrepr.h' file not found
#               #include "longintrepr.h"
#                        ^~~~~~~~~~~~~~~
#             1 error generated.
#             error: command '/usr/bin/clang' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for thinc
#         Running setup.py clean for thinc
#         Building wheel for blis (setup.py): started
#         Building wheel for blis (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [92 lines of output]
#             BLIS_COMPILER? None
#             /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#             !!
#
#                     ********************************************************************************
#                     Requirements should be satisfied by a PEP 517 installer.
#                     If you are using pip, you can try `pip install --use-pep517`.
#                     ********************************************************************************
#
#             !!
#               dist.fetch_build_eggs(dist.setup_requires)
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.macosx-11.0-arm64-cpython-311
#             creating build/lib.macosx-11.0-arm64-cpython-311/blis
#             copying blis/benchmark.py -> build/lib.macosx-11.0-arm64-cpython-311/blis
#             copying blis/__init__.py -> build/lib.macosx-11.0-arm64-cpython-311/blis
#             copying blis/about.py -> build/lib.macosx-11.0-arm64-cpython-311/blis
#             creating build/lib.macosx-11.0-arm64-cpython-311/blis/tests
#             copying blis/tests/__init__.py -> build/lib.macosx-11.0-arm64-cpython-311/blis/tests
#             copying blis/tests/test_dotv.py -> build/lib.macosx-11.0-arm64-cpython-311/blis/tests
#             copying blis/tests/test_gemm.py -> build/lib.macosx-11.0-arm64-cpython-311/blis/tests
#             copying blis/tests/common.py -> build/lib.macosx-11.0-arm64-cpython-311/blis/tests
#             copying blis/cy.pyx -> build/lib.macosx-11.0-arm64-cpython-311/blis
#             copying blis/py.pyx -> build/lib.macosx-11.0-arm64-cpython-311/blis
#             copying blis/__init__.pxd -> build/lib.macosx-11.0-arm64-cpython-311/blis
#             copying blis/cy.pxd -> build/lib.macosx-11.0-arm64-cpython-311/blis
#             running build_ext
#             unix
#             py_compiler gcc
#             {'TRAVIS_ARCH': 'amd64', 'rvm_bin_path': '/Users/travis/.rvm/bin', 'NVM_CD_FLAGS': '', 'GEM_HOME': '/Users/travis/.rvm/gems/ruby-2.4.3', 'HAS_JOSH_K_SEAL_OF_APPROVAL': 'true', 'SHELL': '/bin/bash', 'TERM': 'xterm', 'TRAVIS_TEST_RESULT': '', 'PYTHON_EXE': '/Users/travis/build/explosion/cython-blis/venv/bin/python', 'TMPDIR': '/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/', 'IRBRC': '/Users/travis/.rvm/rubies/ruby-2.4.3/.irbrc', 'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.KSqzJVi3Ll/Render', 'TRAVIS_COMMIT': '2435bb60768369ae2d5b4b056bc12a80333f6658', 'TRAVIS_APT_PROXY': 'http://build-cache.travisci.net', 'TRAVIS_OS_NAME': 'osx', 'TRAVIS_JOB_NAME': '', 'OLDPWD': '/Users/travis/build/explosion/cython-blis', 'TRAVIS_INTERNAL_RUBY_REGEX': '^ruby-(2\\.[0-4]\\.[0-9]|1\\.9\\.3)', 'MY_RUBY_HOME': '/Users/travis/.rvm/rubies/ruby-2.4.3', 'TRAVIS_ROOT': '/', 'LC_ALL': 'en_US.UTF-8', 'TRAVIS_TIMER_ID': '367ffaac', 'USER': 'travis', 'NVM_DIR': '/Users/travis/.nvm', 'ANSI_GREEN': '\\033', '_system_type': 'Darwin', 'TRAVIS_INFRA': 'macstadium', 'TRAVIS_LANGUAGE': 'generic', 'rvm_path': '/Users/travis/.rvm', 'ANSI_RESET': '\\033', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.TiElbGqhQ7/Listeners', 'TRAVIS_DIST': 'notset', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'TRAVIS': 'true', 'ANSI_YELLOW': '\\033', 'TRAVIS_REPO_SLUG': 'explosion/cython-blis', 'PAGER': 'cat', 'TRAVIS_PULL_REQUEST': 'false', 'TRAVIS_COMMIT_MESSAGE': 'Try to fix travis export', 'TRAVIS_BUILD_STAGE_NAME': '', 'VIRTUAL_ENV': '/Users/travis/build/explosion/cython-blis/venv', 'TRAVIS_CMD': 'if [[ "$TRAVIS_OS_NAME" == "osx" ]]; then ./bin/generate-make-jsonl darwin x86_64 --export; fi', 'rvm_prefix': '/Users/travis', 'PATH': '/Users/travis/build/explosion/cython-blis/venv/bin:/Users/travis/.rvm/gems/ruby-2.4.3/bin:/Users/travis/.rvm/gems/ruby-2.4.3@global/bin:/Users/travis/.rvm/rubies/ruby-2.4.3/bin:/Users/travis/.rvm/bin:/Users/travis/bin:/Users/travis/.local/bin:/Users/travis/.nvm/versions/node/v6.14.3/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin', 'TRAVIS_TMPDIR': '/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/tmp.dYZ1JSlR', 'TRAVIS_JOB_WEB_URL': 'https://travis-ci.org/explosion/cython-blis/jobs/506249336', 'TRAVIS_OSX_IMAGE': '', 'TRAVIS_PULL_REQUEST_SHA': '', 'TRAVIS_BUILD_WEB_URL': 'https://travis-ci.org/explosion/cython-blis/builds/506249333', 'UNICODE_WIDTH': '32', 'PWD': '/Users/travis/build/explosion/cython-blis/flame-blis', 'CONTINUOUS_INTEGRATION': 'true', 'LANG': 'en_US.UTF-8', 'XPC_FLAGS': '0x0', '_system_arch': 'x86_64', 'TRAVIS_ENABLE_INFRA_DETECTION': 'true', '_system_version': '10.13', 'TRAVIS_SUDO': 'true', 'TRAVIS_ALLOW_FAILURE': 'false', 'TRAVIS_TAG': '', 'XPC_SERVICE_NAME': '0', 'TRAVIS_HOME': '/Users/travis', 'MB_PYTHON_VERSION': '3.6', 'CXX': 'clang++', 'rvm_version': '1.29.3 (latest)', 'TRAVIS_INIT': 'notset', 'HOME': '/Users/travis', 'PS4': '+', 'SHLVL': '2', 'rvm_pretty_print_flag': 'auto', 'TRAVIS_EVENT_TYPE': 'push', 'TRAVIS_JOB_NUMBER': '511.3', 'ANSI_CLEAR': '\\033[0K', 'CI': 'true', 'TRAVIS_TIMER_START_TIME': '1552568307662747000', 'TRAVIS_BUILD_ID': '506249333', 'LOGNAME': 'travis', 'MACOSX_DEPLOYMENT_TARGET': '10.7', 'GEM_PATH': '/Users/travis/.rvm/gems/ruby-2.4.3:/Users/travis/.rvm/gems/ruby-2.4.3@global', 'TRAVIS_PULL_REQUEST_SLUG': '', 'DEBIAN_FRONTEND': 'noninteractive', 'TRAVIS_SECURE_ENV_VARS': 'false', 'PIP_CMD': '/Users/travis/build/explosion/cython-blis/venv/bin/pip', 'NVM_BIN': '/Users/travis/.nvm/versions/node/v6.14.3/bin', 'TRAVIS_APP_HOST': 'build.travis-ci.org', 'GIT_ASKPASS': 'echo', 'DISPLAY': '/private/tmp/com.apple.launchd.uF8XjeYY64/org.macosforge.xquartz:0', 'TRAVIS_BRANCH': 'update-blis', 'CC': 'clang', 'TRAVIS_COMMIT_RANGE': '9aa6c2ee9c3b...2435bb607683', 'PLAT': 'x86_64', 'TRAVIS_PULL_REQUEST_BRANCH': '', 'RUBY_VERSION': 'ruby-2.4.3', 'ANSI_RED': '\\033', 'TRAVIS_JOB_ID': '506249336', 'TRAVIS_BUILD_DIR': '/Users/travis/build/explosion/cython-blis', '_system_name': ...
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/bulldozer/bli_cntx_init_bulldozer.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_bulldozer.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/excavator/bli_cntx_init_excavator.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_excavator.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/generic/bli_cntx_init_generic.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_generic.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/haswell/bli_cntx_init_haswell.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_haswell.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/penryn/bli_cntx_init_penryn.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_penryn.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/piledriver/bli_cntx_init_piledriver.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_piledriver.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/sandybridge/bli_cntx_init_sandybridge.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_sandybridge.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/steamroller/bli_cntx_init_steamroller.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_steamroller.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/config/zen/bli_cntx_init_zen.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_cntx_init_zen.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang -c /private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_asm_d8x4.c -o /var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_gemm_sandybridge_asm_d8x4.o -O3 -mavx -mfpmath=sse -march=corei7-avx -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64
#             clang: error: unsupported argument 'corei7-avx' to option '-march='
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 34, in <module>
#               File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/setup.py", line 239, in <module>
#                 setup(
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/__init__.py", line 103, in setup
#                 return distutils.core.setup(**attrs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 185, in setup
#                 return run_commands(dist)
#                        ^^^^^^^^^^^^^^^^^^
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#                 dist.run_commands()
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#                 self.run_command(cmd)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/dist.py", line 989, in run_command
#                 super().run_command(command)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#                 cmd_obj.run()
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/wheel/bdist_wheel.py", line 364, in run
#                 self.run_command("build")
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/dist.py", line 989, in run_command
#                 super().run_command(command)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#                 cmd_obj.run()
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#                 self.run_command(cmd_name)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#                 self.distribution.run_command(command)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/dist.py", line 989, in run_command
#                 super().run_command(command)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#                 cmd_obj.run()
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py", line 345, in run
#                 self.build_extensions()
#               File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/setup.py", line 103, in build_extensions
#                 objects = self.compile_objects(compiler.split("-")[0], arch, OBJ_DIR)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/setup.py", line 188, in compile_objects
#                 objects.append(self.build_object(env=env, **spec))
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/setup.py", line 201, in build_object
#                 subprocess.check_call(command, cwd=BLIS_DIR)
#               File "/Users/bernardoquindimil/miniconda3/lib/python3.11/subprocess.py", line 413, in check_call
#                 raise CalledProcessError(retcode, cmd)
#             subprocess.CalledProcessError: Command '['clang', '-c', '/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_asm_d8x4.c', '-o', '/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/tmpx2n3fsah/bli_gemm_sandybridge_asm_d8x4.o', '-O3', '-mavx', '-mfpmath=sse', '-march=corei7-avx', '-fPIC', '-std=c99', '-D_POSIX_C_SOURCE=200112L', '-DBLIS_VERSION_STRING="0.5.1"', '-DBLIS_IS_BUILDING_LIBRARY', '-Iinclude/darwin-x86_64', '-I./frame/3/', '-I./frame/ind/ukernels/', '-I./frame/1m/', '-I./frame/1f/', '-I./frame/1/', '-I./frame/include', '-I/private/var/folders/fc/g29yl9x15nq9_jmdqtk6q1_80000gn/T/pip-install-e0onnwpa/blis_4579fc82dd884947bc7c5eb5608c092b/blis/_src/include/darwin-x86_64']' returned non-zero exit status 1.
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for blis
#         Running setup.py clean for blis
#       Failed to build thinc blis
#       ERROR: Failed to build installable wheels for some pyproject.toml based projects (thinc, blis)
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# To install the requirements for the entire chapter, uncomment the lines below and run this cell

# ===========================

# try :
#     import google.colab
#     !curl https://raw.githubusercontent.com/practical-nlp/practical-nlp/master/Ch3/ch3-requirements.txt | xargs -n 1 -L 1 pip install
# except ModuleNotFoundError :
#     !pip install -r "ch3-requirements.txt"

# ===========================

# %%
import os
import wget
import gzip
import shutil

gn_vec_path = "GoogleNews-vectors-negative300.bin"
if not os.path.exists("GoogleNews-vectors-negative300.bin"):
    if not os.path.exists("../Ch2/GoogleNews-vectors-negative300.bin"):
        #Downloading the reqired model
        if not os.path.exists("../Ch2/GoogleNews-vectors-negative300.bin.gz"):
            if not os.path.exists("GoogleNews-vectors-negative300.bin.gz"):
                wget.download("https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz")
            gn_vec_zip_path = "GoogleNews-vectors-negative300.bin.gz"
        else:
            gn_vec_zip_path = "../Ch2/GoogleNews-vectors-negative300.bin.gz"
        #Extracting the required model
        with gzip.open(gn_vec_zip_path, 'rb') as f_in:
            with open(gn_vec_path, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
    else:
        gn_vec_path = "../Ch2/" + gn_vec_path

print(f"Model at {gn_vec_path}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 12
#      10 if not os.path.exists("../Ch2/GoogleNews-vectors-negative300.bin.gz"):
#      11     if not os.path.exists("GoogleNews-vectors-negative300.bin.gz"):
# ---> 12         wget.download("https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz")
#      13     gn_vec_zip_path = "GoogleNews-vectors-negative300.bin.gz"
#      14 else:
#
# File ~/miniconda3/lib/python3.11/site-packages/wget.py:526, in download(url, out, bar)
#     524 else:
#     525     binurl = url
# --> 526 (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527 filename = detect_filename(url, out, headers)
#     528 if outdir:
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
#     242     headers = fp.info()
#     244     # Just return the local path and the "headers" for file://
#     245     # URLs. No sense in performing a copy unless requested.
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
import warnings #This module ignores the various types of warnings generated
warnings.filterwarnings("ignore") 

import psutil #This module helps in retrieving information on running processes and system resource utilization
process = psutil.Process(os.getpid())
from psutil import virtual_memory
mem = virtual_memory()

import time #This module is used to calculate the time

# %%
from gensim.models import Word2Vec, KeyedVectors
pretrainedpath = gn_vec_path

#Load W2V model. This will take some time, but it is a one time effort! 
pre = process.memory_info().rss
print("Memory used in GB before Loading the Model: %0.2f"%float(pre/(10**9))) #Check memory usage before loading the model
print('-'*10)

start_time = time.time() #Start the timer
ttl = mem.total #Toal memory available

w2v_model = KeyedVectors.load_word2vec_format(pretrainedpath, binary=True) #load the model
print("%0.2f seconds taken to load"%float(time.time() - start_time)) #Calculate the total time elapsed since starting the timer
print('-'*10)

print('Finished loading Word2Vec')
print('-'*10)

post = process.memory_info().rss
print("Memory used in GB after Loading the Model: {:.2f}".format(float(post/(10**9)))) #Calculate the memory used after loading the model
print('-'*10)

print("Percentage increase in memory usage: {:.2f}% ".format(float((post/pre)*100))) #Percentage increase in memory after loading the model
print('-'*10)

print("Numver of words in vocablulary: ",len(w2v_model.vocab)) #Number of words in the vocabulary.
# Out:
# Memory used in GB before Loading the Model: 0.17
# ----------
# 46.47 seconds taken to load
# ----------
# Finished loading Word2Vec
# ----------
# Memory used in GB after Loading the Model: 5.06
# ----------
# Percentage increase in memory usage: 3030.65%
# ----------
# Numver of words in vocablulary:  3000000

# %%
#Let us examine the model by knowing what the most similar words are, for a given word!
w2v_model.most_similar('beautiful')
# Out:
# [('gorgeous', 0.8353004455566406),
#  ('lovely', 0.810693621635437),
#  ('stunningly_beautiful', 0.7329413890838623),
#  ('breathtakingly_beautiful', 0.7231341004371643),
#  ('wonderful', 0.6854087114334106),
#  ('fabulous', 0.6700063943862915),
#  ('loveliest', 0.6612576246261597),
#  ('prettiest', 0.6595001816749573),
#  ('beatiful', 0.6593326330184937),
#  ('magnificent', 0.6591402292251587)]

# %%
#Let us try with another word! 
w2v_model.most_similar('toronto')
# Out:
# [('montreal', 0.698411226272583),
#  ('vancouver', 0.6587257385253906),
#  ('nyc', 0.6248831748962402),
#  ('alberta', 0.6179691553115845),
#  ('boston', 0.611499547958374),
#  ('calgary', 0.61032634973526),
#  ('edmonton', 0.6100261211395264),
#  ('canadian', 0.5944076776504517),
#  ('chicago', 0.5911980271339417),
#  ('springfield', 0.5888351202011108)]

# %%
#What is the vector representation for a word? 
w2v_model['computer']
# Out:
# array([ 1.07421875e-01, -2.01171875e-01,  1.23046875e-01,  2.11914062e-01,
#        -9.13085938e-02,  2.16796875e-01, -1.31835938e-01,  8.30078125e-02,
#         2.02148438e-01,  4.78515625e-02,  3.66210938e-02, -2.45361328e-02,
#         2.39257812e-02, -1.60156250e-01, -2.61230469e-02,  9.71679688e-02,
#        -6.34765625e-02,  1.84570312e-01,  1.70898438e-01, -1.63085938e-01,
#        -1.09375000e-01,  1.49414062e-01, -4.65393066e-04,  9.61914062e-02,
#         1.68945312e-01,  2.60925293e-03,  8.93554688e-02,  6.49414062e-02,
#         3.56445312e-02, -6.93359375e-02, -1.46484375e-01, -1.21093750e-01,
#        -2.27539062e-01,  2.45361328e-02, -1.24511719e-01, -3.18359375e-01,
#        -2.20703125e-01,  1.30859375e-01,  3.66210938e-02, -3.63769531e-02,
#        -1.13281250e-01,  1.95312500e-01,  9.76562500e-02,  1.26953125e-01,
#         6.59179688e-02,  6.93359375e-02,  1.02539062e-02,  1.75781250e-01,
#        -1.68945312e-01,  1.21307373e-03, -2.98828125e-01, -1.15234375e-01,
#         5.66406250e-02, -1.77734375e-01, -2.08984375e-01,  1.76757812e-01,
#         2.03125000e-01, -4.78515625e-02,  1.80664062e-02, -8.54492188e-02,
#        -2.48046875e-01, -3.39843750e-01, -2.83203125e-02,  1.05468750e-01,
#        -2.14843750e-01, -8.74023438e-02,  7.12890625e-02,  1.87500000e-01,
#        -1.12304688e-01,  2.73437500e-01, -3.26171875e-01, -1.77734375e-01,
#        -4.24804688e-02, -2.69531250e-01,  6.64062500e-02, -6.88476562e-02,
#        -1.99218750e-01, -7.03125000e-02, -2.43164062e-01, -3.66210938e-02,
#        -7.37304688e-02, -1.77734375e-01,  9.17968750e-02, -1.25000000e-01,
#        -1.65039062e-01, -3.57421875e-01, -2.85156250e-01, -1.66992188e-01,
#         1.97265625e-01, -1.53320312e-01,  2.31933594e-02,  2.06054688e-01,
#         1.80664062e-01, -2.74658203e-02, -1.92382812e-01, -9.61914062e-02,
#        -1.06811523e-02, -4.73632812e-02,  6.54296875e-02, -1.25732422e-02,
#         1.78222656e-02, -8.00781250e-02, -2.59765625e-01,  9.37500000e-02,
#        -7.81250000e-02,  4.68750000e-02, -2.22167969e-02,  1.86767578e-02,
#         3.11279297e-02,  1.04980469e-02, -1.69921875e-01,  2.58789062e-02,
#        -3.41796875e-02, -1.44042969e-02, -5.46875000e-02, -8.78906250e-02,
#         1.96838379e-03,  2.23632812e-01, -1.36718750e-01,  1.75781250e-01,
#        -1.63085938e-01,  1.87500000e-01,  3.44238281e-02, -5.63964844e-02,
#        -2.27689743e-05,  4.27246094e-02,  5.81054688e-02, -1.07910156e-01,
#        -3.88183594e-02, -2.69531250e-01,  3.34472656e-02,  9.81445312e-02,
#         5.63964844e-02,  2.23632812e-01, -5.49316406e-02,  1.46484375e-01,
#         5.93261719e-02, -2.19726562e-01,  6.39648438e-02,  1.66015625e-02,
#         4.56542969e-02,  3.26171875e-01, -3.80859375e-01,  1.70898438e-01,
#         5.66406250e-02, -1.04492188e-01,  1.38671875e-01, -1.57226562e-01,
#         3.23486328e-03, -4.80957031e-02, -2.48046875e-01, -6.20117188e-02],
#       dtype=float32)

# %%
#What if I am looking for a word that is not in this vocabulary?
w2v_model['practicalnlp']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-354849ef77a2> in <module>()
#       1 #What if I am looking for a word that is not in this vocabulary?
# ----> 2 w2v_model['practicalnlp']
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     335         if isinstance(entities, string_types):
#     336             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 337             return self.get_vector(entities)
#     338
#     339         return vstack([self.get_vector(entity) for entity in entities])
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     453
#     454     def get_vector(self, word):
# --> 455         return self.word_vec(word)
#     456
#     457     def words_closer_than(self, w1, w2):
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     450             return result
#     451         else:
# --> 452             raise KeyError("word '%s' not in vocabulary" % word)
#     453
#     454     def get_vector(self, word):
#
# KeyError: "word 'practicalnlp' not in vocabulary"

# %% [markdown]
# #### Two things to note while using pre-trained models:
#
#
# 1.   Tokens/Words are always lowercased. If a word is not in the vocabulary,   the model throws an exception.
# 2.   So, it is always a good idea to encapsulate those statements in try/except blocks.

# %% [markdown]
# # 2. Getting the embedding representation for full text
#
# We have seen how to get embedding vectors for single words. How do we use them to get such a representation for a full text? A simple way is to just sum or average the embeddings for individual words. We will see an example of this using Word2Vec in Chapter 4. Let us see a small example using another NLP library Spacy - which we saw earlier in Chapter 2 too.

# %%
# !python -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: en_core_web_md==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.5/en_core_web_md-2.2.5.tar.gz#egg=en_core_web_md==2.2.5 in /usr/local/lib/python3.7/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_md==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (7.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (57.2.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.19.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (4.41.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (4.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (3.5.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%